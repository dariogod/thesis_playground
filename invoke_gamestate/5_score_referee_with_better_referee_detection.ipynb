# %%
# !pip install -e visualization/ -q

# %%
import os
from pathlib import Path
import shutil
from typing import Optional
from visualization.visualizer import draw_frame, get_frame_info, create_video, get_unique_frame_ids
import cv2
import json
from tqdm import tqdm
from visualization.visualizer import FrameInfo


json_files = os.listdir("data/gamestate_output")

referee_detected_videos = []
all_videos = []
for json_file in json_files:
    json_file = f"data/gamestate_output/{json_file}"
    if "action" not in json_file:
        continue

    # Check if file exists
    if not os.path.exists(json_file):
        msg = f"Error: JSON file '{json_file}' not found."
        raise ValueError(msg)

    # Get filename without extension for output folder
    filename = Path(json_file).stem

    # Get unique frame IDs
    frame_ids = get_unique_frame_ids(json_file)

    if not frame_ids:
        msg = "Error: No frames found in the JSON file"
        raise ValueError(msg)

    video_info = {}
    for frame_id in frame_ids:
        frame_info = get_frame_info(json_file, frame_id)
        video_info[frame_id] = frame_info.model_dump()

    os.makedirs("data/processed_gamestate_output", exist_ok=True)
    with open("data/processed_gamestate_output/" + filename + ".json", "w") as f:
        json.dump(video_info, f)

    # Check if referee is detected
    referee_detected = False
    for frame_id, frame_info in video_info.items():
        frame_info = FrameInfo.model_validate(frame_info)
        for player in frame_info.players:
            if player.role == "referee":
                referee_detected = True
                break
    
    if referee_detected:
        referee_detected_videos.append(filename)
    all_videos.append(filename)

# %%
import os
import json
from visualization.visualizer import FrameInfo

processed_dir = "data/processed_gamestate_output"

referee_detected_videos = []
all_videos = []
for file in os.listdir(processed_dir):
    if not file.endswith(".json"):
        continue
    action_name = file.split(".json")[0]
    with open(os.path.join(processed_dir, file), "r") as f:
        video_info = json.load(f)
    
    # Check if referee is detected
    referee_detected = False
    for frame_id, frame_info in video_info.items():
        frame_info = FrameInfo.model_validate(frame_info)
        for player in frame_info.players:
            if player.role == "referee":
                referee_detected = True
                break
    
    if referee_detected:
        referee_detected_videos.append(action_name)
    all_videos.append(action_name)

# %%
print(len(referee_detected_videos))
print(len(all_videos))
# Out:
# 224
# 400

# %%
print(referee_detected_videos)

with open("referee_detected_videos.json", "w") as f:
    json.dump(referee_detected_videos, f)
# Out:
# ['action_2230', 'action_2725', 'action_1670', 'action_1959', 'action_2226', 'action_637', 'action_2508', 'action_1975', 'action_2089', 'action_477', 'action_2748', 'action_1871', 'action_1037', 'action_573', 'action_1963', 'action_748', 'action_461', 'action_2836', 'action_2904', 'action_2841', 'action_504', 'action_1943', 'action_2683', 'action_1390', 'action_1685', 'action_1113', 'action_2857', 'action_2085', 'action_2590', 'action_2656', 'action_1304', 'action_2197', 'action_1611', 'action_1492', 'action_2752', 'action_713', 'action_2705', 'action_2354', 'action_2092', 'action_2568', 'action_1485', 'action_36', 'action_20', 'action_704', 'action_587', 'action_568', 'action_1581', 'action_1407', 'action_1542', 'action_769', 'action_2397', 'action_1104', 'action_2285', 'action_964', 'action_1523', 'action_2749', 'action_476', 'action_2572', 'action_1325', 'action_2677', 'action_2724', 'action_2636', 'action_2847', 'action_2797', 'action_2778', 'action_1380', 'action_1400', 'action_1545', 'action_2739', 'action_1210', 'action_345', 'action_2703', 'action_2631', 'action_1949', 'action_2723', 'action_1676', 'action_723', 'action_1267', 'action_1565', 'action_1836', 'action_534', 'action_1861', 'action_2871', 'action_1524', 'action_2758', 'action_1932', 'action_2164', 'action_1748', 'action_1820', 'action_934', 'action_466', 'action_1821', 'action_132', 'action_2718', 'action_958', 'action_2763', 'action_667', 'action_2237', 'action_2149', 'action_1591', 'action_893', 'action_1657', 'action_2313', 'action_997', 'action_1991', 'action_2651', 'action_539', 'action_954', 'action_407', 'action_2411', 'action_2041', 'action_2807', 'action_1694', 'action_1913', 'action_1505', 'action_1155', 'action_717', 'action_2243', 'action_33', 'action_9', 'action_1496', 'action_1750', 'action_72', 'action_1091', 'action_1838', 'action_1906', 'action_2629', 'action_2150', 'action_1814', 'action_1681', 'action_845', 'action_1947', 'action_445', 'action_2404', 'action_1156', 'action_804', 'action_1967', 'action_87', 'action_1121', 'action_2473', 'action_1463', 'action_1199', 'action_2760', 'action_1009', 'action_1818', 'action_1361', 'action_673', 'action_2777', 'action_2798', 'action_798', 'action_1399', 'action_2274', 'action_2825', 'action_921', 'action_2608', 'action_2425', 'action_940', 'action_1854', 'action_1507', 'action_1911', 'action_151', 'action_2405', 'action_405', 'action_2203', 'action_1585', 'action_2716', 'action_242', 'action_2346', 'action_2468', 'action_1614', 'action_983', 'action_1439', 'action_1985', 'action_2350', 'action_176', 'action_930', 'action_2475', 'action_2033', 'action_1218', 'action_863', 'action_2658', 'action_398', 'action_2623', 'action_1371', 'action_1367', 'action_2727', 'action_253', 'action_1982', 'action_1605', 'action_1490', 'action_2195', 'action_584', 'action_750', 'action_615', 'action_951', 'action_2506', 'action_639', 'action_2228', 'action_1957', 'action_1054', 'action_1392', 'action_1691', 'action_443', 'action_506', 'action_1629', 'action_1501', 'action_1110', 'action_950', 'action_2291', 'action_1700', 'action_2710', 'action_1307', 'action_2602', 'action_34', 'action_2839', 'action_63', 'action_252', 'action_272', 'action_663', 'action_2659', 'action_1075', 'action_2065', 'action_1864', 'action_1825']

# %%
print(f"Only {len(referee_detected_videos)} out of {len(all_videos)} videos have a referee detected. ({len(referee_detected_videos)/len(all_videos)*100:.2f}%)")
# Out:
# Only 224 out of 400 videos have a referee detected. (56.00%)

# %%
no_offence_actions = os.listdir("data/frames/no_offence")
offence_actions = os.listdir("data/frames/offence")


referee_detected_offence_actions = []
referee_detected_no_offence_actions = []
for referee_detected_video in referee_detected_videos:
    if referee_detected_video in no_offence_actions:
        referee_detected_no_offence_actions.append(referee_detected_video)
    else:
        referee_detected_offence_actions.append(referee_detected_video)

print(f"Referee detected in {len(referee_detected_offence_actions)} out of {len(offence_actions)} videos with offences")
print(f"Referee detected in {len(referee_detected_no_offence_actions)} out of {len(no_offence_actions)} videos without offences")

print(referee_detected_offence_actions[:3])
print(referee_detected_no_offence_actions[:3])
# Out:
# Referee detected in 112 out of 200 videos with offences
# Referee detected in 112 out of 200 videos without offences
# ['action_2226', 'action_637', 'action_2508']
# ['action_2230', 'action_2725', 'action_1670']

# %%
from create_pip_video import create_pip_video

for action_name in referee_detected_videos:
    original_video_path = f"data/Dataset/Train/{action_name}/clip_0.mp4"
    minimap_video_path = f"visualization/output/{action_name}/video/{action_name}.mp4"


    if f"{action_name}.mp4" in os.listdir("data/pip_videos"):
        print(f"Skipping {action_name} because it already exists")
        continue

    create_pip_video(
        original_video_path, 
        minimap_video_path, 
        "data/pip_videos/" + action_name + ".mp4", 
        pip_scale=0.3
    )
# Out:
# Skipping action_2230 because it already exists
# Skipping action_2725 because it already exists
# Skipping action_1670 because it already exists
# Skipping action_1959 because it already exists
# Skipping action_2226 because it already exists
# Skipping action_637 because it already exists
# Skipping action_2508 because it already exists
# Skipping action_1975 because it already exists
# Skipping action_2089 because it already exists
# Skipping action_477 because it already exists
# Skipping action_2748 because it already exists
# Skipping action_1871 because it already exists
# Skipping action_1037 because it already exists
# Skipping action_573 because it already exists
# Skipping action_1963 because it already exists
# Skipping action_748 because it already exists
# Skipping action_461 because it already exists
# Skipping action_2836 because it already exists
# Skipping action_2904 because it already exists
# Skipping action_2841 because it already exists
# Skipping action_504 because it already exists
# Skipping action_1943 because it already exists
# Skipping action_2683 because it already exists
# Skipping action_1390 because it already exists
# Skipping action_1685 because it already exists
# Skipping action_1113 because it already exists
# Skipping action_2857 because it already exists
# Skipping action_2085 because it already exists
# Skipping action_2590 because it already exists
# Skipping action_2656 because it already exists
# Skipping action_1304 because it already exists
# Skipping action_2197 because it already exists
# Skipping action_1611 because it already exists
# Skipping action_1492 because it already exists
# Skipping action_2752 because it already exists
# Skipping action_713 because it already exists
# Skipping action_2705 because it already exists
# Skipping action_2354 because it already exists
# Skipping action_2092 because it already exists
# Skipping action_2568 because it already exists
# Skipping action_1485 because it already exists
# Skipping action_36 because it already exists
# Skipping action_20 because it already exists
# Skipping action_704 because it already exists
# Skipping action_587 because it already exists
# Skipping action_568 because it already exists
# Skipping action_1581 because it already exists
# Skipping action_1407 because it already exists
# Skipping action_1542 because it already exists
# Skipping action_769 because it already exists
# Skipping action_2397 because it already exists
# Skipping action_1104 because it already exists
# Skipping action_2285 because it already exists
# Skipping action_964 because it already exists
# Skipping action_1523 because it already exists
# Skipping action_2749 because it already exists
# Skipping action_476 because it already exists
# Skipping action_2572 because it already exists
# Skipping action_1325 because it already exists
# Skipping action_2677 because it already exists
# Skipping action_2724 because it already exists
# Skipping action_2636 because it already exists
# Skipping action_2847 because it already exists
# Skipping action_2797 because it already exists
# Skipping action_2778 because it already exists
# Skipping action_1380 because it already exists
# Skipping action_1400 because it already exists
# Skipping action_1545 because it already exists
# Skipping action_2739 because it already exists
# Skipping action_1210 because it already exists
# Skipping action_345 because it already exists
# Skipping action_2703 because it already exists
# Skipping action_2631 because it already exists
# Skipping action_1949 because it already exists
# Skipping action_2723 because it already exists
# Skipping action_1676 because it already exists
# Skipping action_723 because it already exists
# Skipping action_1267 because it already exists
# Skipping action_1565 because it already exists
# Skipping action_1836 because it already exists
# Skipping action_534 because it already exists
# Skipping action_1861 because it already exists
# Skipping action_2871 because it already exists
# Skipping action_1524 because it already exists
# Skipping action_2758 because it already exists
# Skipping action_1932 because it already exists
# Skipping action_2164 because it already exists
# Skipping action_1748 because it already exists
# Skipping action_1820 because it already exists
# Skipping action_934 because it already exists
# Skipping action_466 because it already exists
# Skipping action_1821 because it already exists
# Skipping action_132 because it already exists
# Skipping action_2718 because it already exists
# Skipping action_958 because it already exists
# Skipping action_2763 because it already exists
# Skipping action_667 because it already exists
# Skipping action_2237 because it already exists
# Skipping action_2149 because it already exists
# Skipping action_1591 because it already exists
# Skipping action_893 because it already exists
# Skipping action_1657 because it already exists
# Skipping action_2313 because it already exists
# Skipping action_997 because it already exists
# Skipping action_1991 because it already exists
# Skipping action_2651 because it already exists
# Skipping action_539 because it already exists
# Skipping action_954 because it already exists
# Skipping action_407 because it already exists
# Skipping action_2411 because it already exists
# Skipping action_2041 because it already exists
# Skipping action_2807 because it already exists
# Skipping action_1694 because it already exists
# Skipping action_1913 because it already exists
# Skipping action_1505 because it already exists
# Skipping action_1155 because it already exists
# Skipping action_717 because it already exists
# Skipping action_2243 because it already exists
# Skipping action_33 because it already exists
# Skipping action_9 because it already exists
# Skipping action_1496 because it already exists
# Skipping action_1750 because it already exists
# Skipping action_72 because it already exists
# Skipping action_1091 because it already exists
# Skipping action_1838 because it already exists
# Skipping action_1906 because it already exists
# Skipping action_2629 because it already exists
# Skipping action_2150 because it already exists
# Skipping action_1814 because it already exists
# Skipping action_1681 because it already exists
# Skipping action_845 because it already exists
# Skipping action_1947 because it already exists
# Skipping action_445 because it already exists
# Skipping action_2404 because it already exists
# Skipping action_1156 because it already exists
# Skipping action_804 because it already exists
# Skipping action_1967 because it already exists
# Skipping action_87 because it already exists
# Skipping action_1121 because it already exists
# Skipping action_2473 because it already exists
# Skipping action_1463 because it already exists
# Skipping action_1199 because it already exists
# Skipping action_2760 because it already exists
# Skipping action_1009 because it already exists
# Skipping action_1818 because it already exists
# Skipping action_1361 because it already exists
# Skipping action_673 because it already exists
# Skipping action_2777 because it already exists
# Skipping action_2798 because it already exists
# Skipping action_798 because it already exists
# Skipping action_1399 because it already exists
# Skipping action_2274 because it already exists
# Skipping action_2825 because it already exists
# Skipping action_921 because it already exists
# Skipping action_2608 because it already exists
# Skipping action_2425 because it already exists
# Skipping action_940 because it already exists
# Skipping action_1854 because it already exists
# Skipping action_1507 because it already exists
# Skipping action_1911 because it already exists
# Skipping action_151 because it already exists
# Skipping action_2405 because it already exists
# Skipping action_405 because it already exists
# Skipping action_2203 because it already exists
# Skipping action_1585 because it already exists
# Skipping action_2716 because it already exists
# Skipping action_242 because it already exists
# Skipping action_2346 because it already exists
# Skipping action_2468 because it already exists
# Skipping action_1614 because it already exists
# Skipping action_983 because it already exists
# Skipping action_1439 because it already exists
# Skipping action_1985 because it already exists
# Skipping action_2350 because it already exists
# Skipping action_176 because it already exists
# Skipping action_930 because it already exists
# Skipping action_2475 because it already exists
# Skipping action_2033 because it already exists
# Skipping action_1218 because it already exists
# Skipping action_863 because it already exists
# Skipping action_2658 because it already exists
# Skipping action_398 because it already exists
# Skipping action_2623 because it already exists
# Skipping action_1371 because it already exists
# Skipping action_1367 because it already exists
# Skipping action_2727 because it already exists
# Skipping action_253 because it already exists
# Skipping action_1982 because it already exists
# Skipping action_1605 because it already exists
# Skipping action_1490 because it already exists
# Skipping action_2195 because it already exists
# Skipping action_584 because it already exists
# Skipping action_750 because it already exists
# Skipping action_615 because it already exists
# Skipping action_951 because it already exists
# Skipping action_2506 because it already exists
# Skipping action_639 because it already exists
# Skipping action_2228 because it already exists
# Skipping action_1957 because it already exists
# Skipping action_1054 because it already exists
# Skipping action_1392 because it already exists
# Skipping action_1691 because it already exists
# Skipping action_443 because it already exists
# Skipping action_506 because it already exists
# Skipping action_1629 because it already exists
# Skipping action_1501 because it already exists
# Skipping action_1110 because it already exists
# Skipping action_950 because it already exists
# Skipping action_2291 because it already exists
# Skipping action_1700 because it already exists
# Skipping action_2710 because it already exists
# Skipping action_1307 because it already exists
# Skipping action_2602 because it already exists
# Skipping action_34 because it already exists
# Skipping action_2839 because it already exists
# Skipping action_63 because it already exists
# Skipping action_252 because it already exists
# Skipping action_272 because it already exists
# Skipping action_663 because it already exists
# Skipping action_2659 because it already exists
# Skipping action_1075 because it already exists
# Skipping action_2065 because it already exists
# Skipping action_1864 because it already exists
# Skipping action_1825 because it already exists

# %% [markdown]
# https://pmc.ncbi.nlm.nih.gov/articles/PMC7820113/

# %% [markdown]
# ## Score the referee based on metrics

# %%
import numpy as np
import json

def referee_position_score(ref_pos, action_pos, d_diag, 
                           d_action_optimal=20, sigma_action=5,
                           sigma_diag=10):
    x_r, y_r = ref_pos
    x_a, y_a = action_pos
    d_action = np.linalg.norm([x_r - x_a, y_r - y_a])

    # Score for action proximity (peak at 20m, penalizes further/closer)
    score_action = np.exp(-((d_action - d_action_optimal)**2) / (2 * sigma_action**2))

    # Score for diagonal alignment (peak at 0m, falls off with distance)
    score_diag = np.exp(-(d_diag**2) / (2 * sigma_diag**2))

    # Combine both scores
    score_total = (score_action + score_diag) / 2

    return round(score_total, 3)

# Process all referee detected videos (or a subset for testing)
results = {}

for action_name in referee_detected_videos:
    video_info = json.load(open(f"data/processed_gamestate_output/{action_name}.json"))
    
    frame_scores = []
    
    for frame_id, frame_info in video_info.items():
        frame_info = FrameInfo.model_validate(frame_info)
        
        # Find the referee
        referee = None
        for player in frame_info.players:
            if player.role == 'referee':
                referee = player
                break
        
        if referee and frame_info.point_of_action and frame_info.dist_to_diagonal:
            # Get referee position
            ref_pos = (referee.position.x, referee.position.y)
            
            # Get point of action position
            action_pos = (frame_info.point_of_action.x, frame_info.point_of_action.y)
            
            # Get distance to diagonal
            d_diag = frame_info.dist_to_diagonal
            
            # Calculate score
            score = referee_position_score(ref_pos, action_pos, d_diag)
            frame_scores.append(score)
                
    
    # Calculate overall score for the clip
    if frame_scores:
        avg_score = round(sum(frame_scores) / len(frame_scores), 3)
        results[action_name] = {
            "num_frames": len(frame_scores),
            "avg_score": avg_score,
            "min_score": min(frame_scores),
            "max_score": max(frame_scores)
        }
    else:
        print(f"No referee detected in frames for {action_name}")

# Save overall results to a file
with open("referee_scores.json", "w") as f:
    json.dump(results, f, indent=2)

# %%
with open("referee_scores.json", "r") as f:
    results = json.load(f)

offence_results = {}
no_offence_results = {}
for action_name, result in results.items():
    if action_name in offence_actions:
        offence_results[action_name] = result
    elif action_name in no_offence_actions:
        no_offence_results[action_name] = result

print(len(offence_results))
print(len(no_offence_results))
# Out:
# 112
# 112

# %%
# Remove outliers using IQR method
def remove_outliers(data_dict):
    avg_scores = [result["avg_score"] for result in data_dict.values()]
    
    # Calculate Q1, Q3 and IQR
    q1 = np.percentile(avg_scores, 25)
    q3 = np.percentile(avg_scores, 75)
    iqr = q3 - q1
    
    # Define bounds
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    
    # Filter out outliers
    filtered_dict = {
        action: result for action, result in data_dict.items()
        if lower_bound <= result["avg_score"] <= upper_bound
    }
    
    return filtered_dict

# Remove outliers from both sets
offence_results = remove_outliers(offence_results)
no_offence_results = remove_outliers(no_offence_results)

print("After removing outliers:")
print(f"Number of offence clips: {len(offence_results)}")
print(f"Number of no-offence clips: {len(no_offence_results)}")
# Out:
# After removing outliers:
# Number of offence clips: 112
# Number of no-offence clips: 112

# %%
# Calculate statistics for offence results
offence_avg_scores = [result["avg_score"] for result in offence_results.values()]
offence_min_scores = [result["min_score"] for result in offence_results.values()]
offence_max_scores = [result["max_score"] for result in offence_results.values()]

print("\nOffence Results Statistics:")
print(f"Average scores: mean={round(sum(offence_avg_scores)/len(offence_avg_scores), 3)}, min={min(offence_avg_scores)}, max={max(offence_avg_scores)}")
print(f"Minimum scores: mean={round(sum(offence_min_scores)/len(offence_min_scores), 3)}, min={min(offence_min_scores)}, max={max(offence_min_scores)}")
print(f"Maximum scores: mean={round(sum(offence_max_scores)/len(offence_max_scores), 3)}, min={min(offence_max_scores)}, max={max(offence_max_scores)}")

# Calculate statistics for no-offence results
no_offence_avg_scores = [result["avg_score"] for result in no_offence_results.values()]
no_offence_min_scores = [result["min_score"] for result in no_offence_results.values()]
no_offence_max_scores = [result["max_score"] for result in no_offence_results.values()]

print("\nNo Offence Results Statistics:")
print(f"Average scores: mean={round(sum(no_offence_avg_scores)/len(no_offence_avg_scores), 3)}, min={min(no_offence_avg_scores)}, max={max(no_offence_avg_scores)}")
print(f"Minimum scores: mean={round(sum(no_offence_min_scores)/len(no_offence_min_scores), 3)}, min={min(no_offence_min_scores)}, max={max(no_offence_min_scores)}")
print(f"Maximum scores: mean={round(sum(no_offence_max_scores)/len(no_offence_max_scores), 3)}, min={min(no_offence_max_scores)}, max={max(no_offence_max_scores)}")
# Out:
# Offence Results Statistics:
# Average scores: mean=0.39, min=0.001, max=0.808
# Minimum scores: mean=0.107, min=0.0, max=0.604
# Maximum scores: mean=0.687, min=0.001, max=1.0
#
# No Offence Results Statistics:
# Average scores: mean=0.38, min=0.0, max=0.808
# Minimum scores: mean=0.138, min=0.0, max=0.59
# Maximum scores: mean=0.671, min=0.0, max=1.0
